# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
test_url = "https://bdfed.stitch.mlbinfra.com/bdfed/stats/player?stitch_env=prod&season=2017&sportId=1&stats=season&group=pitching&gameType=R&limit=25&offset=0&sortStat=earnedRunAverage&order=asc"

# %%
r = requests.get(url=test_url).json()

# %%
r['stats'][1]['era']
# Out:
# '2.31'

# %%
list(r['stats'][0].keys())
# Out:
# ['year',
#  'playerId',
#  'playerName',
#  'type',
#  'rank',
#  'playerFullName',
#  'playerFirstName',
#  'playerLastName',
#  'playerUseName',
#  'playerInitLastName',
#  'teamId',
#  'teamAbbrev',
#  'teamName',
#  'teamShortName',
#  'leagueName',
#  'leagueId',
#  'positionAbbrev',
#  'position',
#  'primaryPositionAbbrev',
#  'winningPercentage',
#  'runsScoredPer9',
#  'battersFaced',
#  'babip',
#  'obp',
#  'slg',
#  'ops',
#  'strikeoutsPer9',
#  'baseOnBallsPer9',
#  'homeRunsPer9',
#  'hitsPer9',
#  'strikesoutsToWalks',
#  'inheritedRunners',
#  'inheritedRunnersScored',
#  'bequeathedRunners',
#  'bequeathedRunnersScored',
#  'stolenBases',
#  'caughtStealing',
#  'qualityStarts',
#  'gamesFinished',
#  'doubles',
#  'triples',
#  'gidp',
#  'gidpOpp',
#  'wildPitches',
#  'balks',
#  'pickoffs',
#  'totalSwings',
#  'swingAndMisses',
#  'ballsInPlay',
#  'runSupport',
#  'strikePercentage',
#  'pitchesPerInning',
#  'pitchesPerPlateAppearance',
# ...

# %%
print(len(list(r['stats'][1].values())))
print(len(list(r['stats'][1].keys())))
# Out:
# 107
# 107

# %%
rows = []
for i in range (0, 25):
    rows.append(list(r['stats'][i].values()))
df = pd.DataFrame(rows, columns=list(r['stats'][0].keys()))
df
# Out:
#     year  playerId         playerName    type  rank     playerFullName  \
# 0   2017    446372       Corey Kluber  player     1       Corey Kluber
# 1   2017    477132    Clayton Kershaw  player     2    Clayton Kershaw
# 2   2017    453286       Max Scherzer  player     3       Max Scherzer
# 3   2017    544931  Stephen Strasburg  player     4  Stephen Strasburg
# 4   2017    592662         Robbie Ray  player     5         Robbie Ray
# 5   2017    519242         Chris Sale  player     6         Chris Sale
# 6   2017    461829       Gio Gonzalez  player     7       Gio Gonzalez
# 7   2017    622663      Luis Severino  player     8      Luis Severino
# 8   2017    573186     Marcus Stroman  player     9     Marcus Stroman
# 9   2017    425844       Zack Greinke  player    10       Zack Greinke
# 10  2017    429722      Ervin Santana  player    11      Ervin Santana
# 11  2017    471911    Carlos Carrasco  player    12    Carlos Carrasco
# ...
